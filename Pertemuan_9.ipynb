# %%
# # -- LIST

# # Kumpulan data angka
# data_angka = [1,5,2,3]
# print(data_angka)

# # Kumpulan data string
# data_string = ["aku","dia","kita"]
# print(data_string)

# # Kumpulan data boolean
# data_boolean = [True, False, True, False]
# print(data_boolean)

# # Kumpulan campuran data
# data_campuran = [1,"bakwan",2,"cireng",True,"adit"]
# print(data_campuran)

# # cara alternatif membuat list
# data_range = range(0,12,2) # range(start, stop, step(interval/jarak antar nilai))
# print(data_range)
# data_list = list(data_range)
# print(data_list)

# membuat list menggunakan perulangan for
# list_for = [i **2 for i in range(0,10)]
# print(list_for)

#  membuat list menggunakan for dengan if
# list_for_if = [i for i in range(0,11) if i !=2]
# print(list_for_if)

# # membuat list menggunakan for tapi yang akan tampil hanya jika angkanya genap

# list_for_if_genap = [x for x in range(0,11) if x % 2 == 0]
# print(list_for_if_genap)

# list_for_if_ganjil = [y for y in range(0,11) if y % 2 != 0]
# print(list_for_if_ganjil)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# Manipulasi List

# %%
# # mengubah, menambah, mengurangi data pada list

# # index  0 (-4)  1 (-3)  2 (-2)   3 (-1)
data = ["Ucup", "Adit", "Dudung", "Anin"]
# data_0 = data[-4]
# print(data_0)

# # data index -(minus) digunakan untuk menampilkan data mulai dari terakhir

# # cara mengambil info panjang jumlah data
# panjang_data = len(data)
# print(f"panjang data adalah {panjang_data}")

# # manipulasi data
# # menambahkan item/data pada list sesuai dengan posisi
# # print(f"data sebelum ditambah : {data}")

# # data.insert(posisi, item/data)
# data.insert(2, "Asep")
# print(f"data setelah ditambah : {data}")

# # menambah item di akhir
# data.append("Ririn")
# print(f"data setelah ditambah : {data}")

# # menambah list
# data_baru = ["Luffy", "Zoro", "Nami", "Robbin"]
# data.extend(data_baru)
# print(f"data setelah digabung : {data}")

# # merubah data
# # kita merubah data index ke-4
# print(data[2])
# data[2] = "Rendi"
# print(f"data setelah diubah : {data}")

# # menghapus data
# data.remove("Dudung")
# print(f"data setelah dihapus : {data}")

# # menghapus data paling belakang
# data.pop()
# print(f"data setelah dihapus yang paling akhir : {data}")
# Out:
# data setelah dihapus yang paling akhir : ['Ucup', 'Adit', 'Dudung']

# %% [markdown]
# Operasi List

# %%
data_angka = [1,7,3,6,0,4,5,4,2,7,9,7,2,3,1]
# print(data_angka)
# print(f"panjang data {len(data_angka)}")

# count data
# jumlah_data_4 = data_angka.count(4)
# print(f"jumlah data angka 4 adalah {jumlah_data_4}")

# ambil posisi/index
data = ["Rendi", "Iqbal", "Gana", "Khairil"]
# print(data)
# index_iqbal = data.index("Iqbal")
# print(f"Index si Iqbal = {index_iqbal} ")

# mengurutkan list dari terkecil ke terbesar
data_angka.sort()
# print(f"data angka sort = \n{data_angka}")

# urutkan data string
data.sort()
# print(f"data string sort = \n{data}")

# membalikkan data / reverse
data_angka.reverse()
# print(f"data angka reverse = \n{data_angka}")

# membalikkan data string
data.reverse()
print(f"data string reverse = \n{data}")
# Out:
# data string reverse =
# ['Rendi', 'Khairil', 'Iqbal', 'Gana']

# %% [markdown]
# Nested List / List Bersarang

# %%
# -- nested list

# data_0 = [1,2]
# data_1 = [3,4]

# data_list_biasa = [1,2,3,4]
# print(f"list biasa = {data_list_biasa}")
# [[1,2],[3,4]] (list didalam list)
# list_2D = [data_0, data_1, 6, 7]
# print(f"list 2D = {list_2D}")

# # contoh penggunaan
peserta_0 = ["Rendi", 25, "Laki-laki"]
peserta_1 = ["Joni", 10, "Laki-laki"]
peserta_2 = ["Anita", 50, "Wanita"]

list_peserta = [peserta_0, peserta_1, peserta_2]
# print(f"info peserta : {list_peserta}")

for peserta in list_peserta:
  print(f"nama\t : {peserta[0]}")
  print(f"usia\t : {peserta[1]}")
  print(f"gender\t : {peserta[2]}\n")
# Out:
# nama	 : Rendi
# usia	 : 25
# gender	 : Laki-laki
#
# nama	 : Joni
# usia	 : 10
# gender	 : Laki-laki
#
# nama	 : Anita
# usia	 : 50
# gender	 : Wanita
